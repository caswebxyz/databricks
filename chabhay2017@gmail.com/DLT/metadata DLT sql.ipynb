# %%
# %sql
create table sourcemetadata(
    sourcemetadaID int,
    sourcefilename string,
    sourcefilepath string,
    sourcefileformat string,
    sourceisActive boolean,
    sourcedelimiter string,
    sourceheader boolean,
    sourcepartitioncolumn string,
    sourcedataquality string,
    sourceistransformation string,
    sourcetransformfunction string,
    sourcefileoptions string,
    sourcetablename string,
    sourceschemaname string,
    scdexpectcolumnlist string,
    scdtype int,
    sequenceby string,
    sourcegroupid int,
    CreatedOn timestamp,
    CreatedBy string,
    ModifiedOn timestamp,
    ModifiedBy string
);

insert into sourcemetadata values (3,'circuit','/Volumes/awsdbx_w1_2358208440317044/poc/circuit/','csv',True,',',True,null,
'{"validate circuitId":"(circuitId IS NOT NULL)","validate name":"(name IS NOT NULL)"}',
null,null,
'{"cloudFiles.Format":"csv","header":True}',
'circuit',
null,
null,
1,
'file_processed_date',
3,
now(),
'admin',
now(),
'admin');

select * from sourcemetadata;
delete from sourcemetadata;

update sourcemetadata set sourcepartitioncolumn = 'circuitid' where sourcemetadaID = 3;
update sourcemetadata set sourcepartitioncolumn = 'raceid' where sourcemetadaID = 4;

insert into sourcemetadata values (4,'race','/Volumes/awsdbx_w1_2358208440317044/poc/race/','csv',True,',',True,null,
'{"validate raceId":"(raceId IS NOT NULL)","validate name":"(name IS NOT NULL)"}',
null,null,
'{"cloudFiles.Format":"csv","header":True}',
'race',
null,
null,
1,
'file_processed_date',
3,
now(),
'admin',
now(),
'admin');


drop table sourceschemaconfig;

create table sourceschemaconfig(
    sourceschemaconfigid int,
    sourcemetadataid int,
    columnname string,
    columndatatype string,
    columnorder int,
    isNullable boolean,
    isSensitive string,
    CreatedOn timestamp,
    CreatedBy string,
    ModifiedOn timestamp,
    ModifiedBy string
);

delete from sourceschemaconfig;

insert into sourceschemaconfig values (1,3,'circuitId','IntegerType',1,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (2,3,'circuitRef','StringType',2,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (3,3,'name','StringType',3,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (4,3,'location','StringType',4,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (5,3,'country','StringType',5,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (6,3,'lat','StringType',6,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (7,3,'lng','StringType',7,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (8,3,'alt','StringType',8,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (9,3,'url','StringType',9,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (10,3,'file_processed_date','StringType',10,'True','No',now(),'admin',now(),'admin');




describe table awsdbx_w1_2358208440317044.default.brz_table_circuit;

select * from sourceschemaconfig;


insert into sourceschemaconfig values (11,4,'raceId','IntegerType',1,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (12,4,'name','StringType',2,'True','No',now(),'admin',now(),'admin');
insert into sourceschemaconfig values (13,4,'file_processed_date','StringType',3,'True','No',now(),'admin',now(),'admin');
